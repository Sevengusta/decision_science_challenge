# %%
import pandas as pd
import numpy as np

# %%
x = np.linspace(0,10,100)
y = np.sin(x) 
z = np.cos(x)

# %%
import matplotlib.pyplot as plt
import seaborn as 
import plotly

# %%
sns.set_theme()

# %%
fig = plt.figure()
plt.plot(x,y, "r--")
plt.plot(x,z, "g-")
plt.xlim(0,10)
plt.show()
